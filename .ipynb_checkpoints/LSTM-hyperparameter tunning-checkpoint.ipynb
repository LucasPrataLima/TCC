# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing import timeseries_dataset_from_array
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, Dropout, Input
import keras
from keras.callbacks import *
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
from scipy.stats import pearsonr

# %%
# Importando dados
data = pd.read_excel(r'Conjunto de Dados Completo Original.xlsx')
data = data[['Chuva_observada (mm)', 'Chuva_Acum (mm)', 'ENA_Grande (MWmed)']]

# %%
# Definindo parâmetros
sequence_length = 12
batch_size = 32
stride = 1
learning_rate = 0.001
train_cut = int(0.7*len(data))


# Escalonando todos os dados para o intervalo entre 0 e 1
scaler = MinMaxScaler()
scaler.fit(data[:train_cut])
data_scaled = scaler.transform(data)

scaler_Y = MinMaxScaler()
scaler_Y.fit(data[['ENA_Grande (MWmed)']][:train_cut])

# Convertendo o array numpy de volta para um DataFrame
data_scaled_df = pd.DataFrame(data_scaled, columns=data.columns)

# Separando inputs e targets
inputs = data_scaled_df[['Chuva_Acum (mm)', 'ENA_Grande (MWmed)']]
inputs = inputs.iloc[:-sequence_length]
targets = data_scaled_df.loc[sequence_length:, 'ENA_Grande (MWmed)']


# Criando o dataset
full_dataset = timeseries_dataset_from_array(
    inputs,
    targets,
    sequence_length=sequence_length,
    batch_size=batch_size,
    shuffle=False
)

# Converte o dataset em listas de arrays para divisão
inputs_list = []
targets_list = []

for batch in full_dataset:
    inputs, targets = batch
    inputs_list.extend(inputs.numpy())
    targets_list.extend(targets.numpy())

# Converte listas para arrays
inputs_array = np.array(inputs_list)
targets_array = np.array(targets_list)

# Divide os dados em treinamento, validação e teste (70%, 20%, 10%)
train_size = int(0.7 * len(inputs_array))
val_size = int(0.2 * len(inputs_array))
test_size = len(inputs_array) - train_size - val_size

x_train = inputs_array[:train_size]
y_train = targets_array[:train_size]

x_val = inputs_array[train_size:train_size + val_size]
y_val = targets_array[train_size:train_size + val_size]

x_test = inputs_array[train_size + val_size:]
y_test = targets_array[train_size + val_size:]

# Cria datasets de treinamento, validação e teste
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size)
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(batch_size)

# %%
len(x_val)
# Out:
# 23

# %%
# Verificando os formatos de inputs e targets
for batch in train_dataset.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (32, 12, 2)
# Target shape: (32,)

# %%
# Definindo a arquitetura do modelo
model = Sequential()
model.add(Input(shape=(inputs.shape[1], inputs.shape[2])))
model.add(LSTM(units=12, return_sequences=True))
model.add(LSTM(units=12))
model.add(Dense(1))

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 12, 12)         │           720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 12)             │         1,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,933 (7.55 KB)
#  Trainable params: 1,933 (7.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Definindo callbacks
earlyStopping = EarlyStopping(monitor='val_loss', verbose=0, patience=30)
mcp_save = ModelCheckpoint('trained_models/LSTM.keras', save_best_only=True, monitor='val_loss')

# Treinando o modelo
history = model.fit(
    train_dataset,
    epochs=2000,
    validation_data=val_dataset,
    callbacks=[earlyStopping, mcp_save],
)
# Out:
# Epoch 1/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0477 - val_loss: 0.0536
# Epoch 2/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0398 - val_loss: 0.0462
# Epoch 3/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0345 - val_loss: 0.0413
# Epoch 4/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0316 - val_loss: 0.0388
# Epoch 5/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0306 - val_loss: 0.0378
# Epoch 6/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0303 - val_loss: 0.0374
# Epoch 7/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0300 - val_loss: 0.0373
# Epoch 8/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0296 - val_loss: 0.0375
# Epoch 9/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0294 - val_loss: 0.0380
# Epoch 10/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0294 - val_loss: 0.0385
# Epoch 11/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0295 - val_loss: 0.0388
# Epoch 12/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0295 - val_loss: 0.0388
# Epoch 13/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0294 - val_loss: 0.0384
# Epoch 14/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0291 - val_loss: 0.0377
# Epoch 15/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0287 - val_loss: 0.0370
# Epoch 16/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0283 - val_loss: 0.0364
# Epoch 17/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0279 - val_loss: 0.0358
# Epoch 18/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0276 - val_loss: 0.0354
# Epoch 19/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0273 - val_loss: 0.0352
# Epoch 20/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0270 - val_loss: 0.0350
# Epoch 21/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0267 - val_loss: 0.0348
# Epoch 22/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0265 - val_loss: 0.0345
# Epoch 23/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0261 - val_loss: 0.0341
# Epoch 24/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0258 - val_loss: 0.0335
# Epoch 25/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0253 - val_loss: 0.0329
# Epoch 26/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0248 - val_loss: 0.0321
# Epoch 27/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0243 - val_loss: 0.0314
# Epoch 28/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0237 - val_loss: 0.0307
# Epoch 29/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0232 - val_loss: 0.0300
# Epoch 30/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0226 - val_loss: 0.0292
# Epoch 31/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0219 - val_loss: 0.0282
# Epoch 32/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0212 - val_loss: 0.0270
# Epoch 33/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0204 - val_loss: 0.0258
# Epoch 34/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0196 - val_loss: 0.0246
# Epoch 35/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0188 - val_loss: 0.0234
# Epoch 36/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0181 - val_loss: 0.0221
# Epoch 37/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0174 - val_loss: 0.0209
# Epoch 38/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0168 - val_loss: 0.0198
# Epoch 39/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0164 - val_loss: 0.0189
# Epoch 40/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0161 - val_loss: 0.0181
# Epoch 41/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0159 - val_loss: 0.0176
# Epoch 42/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0158 - val_loss: 0.0173
# Epoch 43/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0158 - val_loss: 0.0170
# Epoch 44/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0157 - val_loss: 0.0169
# Epoch 45/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0156 - val_loss: 0.0168
# Epoch 46/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0155 - val_loss: 0.0167
# Epoch 47/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0154 - val_loss: 0.0167
# Epoch 48/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0153 - val_loss: 0.0167
# Epoch 49/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0152 - val_loss: 0.0167
# Epoch 50/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0151 - val_loss: 0.0166
# Epoch 51/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0150 - val_loss: 0.0166
# Epoch 52/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0149 - val_loss: 0.0166
# Epoch 53/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0148 - val_loss: 0.0166
# Epoch 54/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0148 - val_loss: 0.0165
# Epoch 55/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0147 - val_loss: 0.0165
# Epoch 56/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0146 - val_loss: 0.0164
# Epoch 57/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0146 - val_loss: 0.0163
# Epoch 58/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0145 - val_loss: 0.0163
# Epoch 59/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0145 - val_loss: 0.0162
# Epoch 60/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0144 - val_loss: 0.0161
# Epoch 61/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0143 - val_loss: 0.0161
# Epoch 62/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0143 - val_loss: 0.0160
# Epoch 63/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0142 - val_loss: 0.0160
# Epoch 64/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0142 - val_loss: 0.0159
# Epoch 65/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0141 - val_loss: 0.0159
# Epoch 66/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0140 - val_loss: 0.0158
# Epoch 67/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0140 - val_loss: 0.0158
# Epoch 68/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0139 - val_loss: 0.0157
# Epoch 69/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0139 - val_loss: 0.0157
# Epoch 70/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0138 - val_loss: 0.0157
# Epoch 71/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0138 - val_loss: 0.0156
# Epoch 72/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0137 - val_loss: 0.0156
# Epoch 73/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0137 - val_loss: 0.0156
# Epoch 74/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0136 - val_loss: 0.0155
# Epoch 75/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0135 - val_loss: 0.0155
# Epoch 76/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0135 - val_loss: 0.0155
# Epoch 77/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0134 - val_loss: 0.0154
# Epoch 78/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0134 - val_loss: 0.0154
# Epoch 79/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0133 - val_loss: 0.0153
# Epoch 80/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0133 - val_loss: 0.0153
# Epoch 81/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0132 - val_loss: 0.0153
# Epoch 82/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0132 - val_loss: 0.0152
# Epoch 83/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0131 - val_loss: 0.0152
# Epoch 84/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0131 - val_loss: 0.0152
# Epoch 85/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0130 - val_loss: 0.0151
# Epoch 86/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0130 - val_loss: 0.0151
# Epoch 87/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0129 - val_loss: 0.0151
# Epoch 88/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0129 - val_loss: 0.0150
# Epoch 89/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0128 - val_loss: 0.0150
# Epoch 90/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0128 - val_loss: 0.0150
# Epoch 91/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0128 - val_loss: 0.0149
# Epoch 92/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0127 - val_loss: 0.0149
# Epoch 93/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0127 - val_loss: 0.0149
# Epoch 94/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0126 - val_loss: 0.0149
# Epoch 95/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0126 - val_loss: 0.0148
# Epoch 96/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0125 - val_loss: 0.0148
# Epoch 97/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0125 - val_loss: 0.0148
# Epoch 98/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0124 - val_loss: 0.0147
# Epoch 99/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0124 - val_loss: 0.0147
# Epoch 100/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0123 - val_loss: 0.0147
# Epoch 101/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0123 - val_loss: 0.0146
# Epoch 102/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0122 - val_loss: 0.0146
# Epoch 103/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0122 - val_loss: 0.0146
# Epoch 104/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0122 - val_loss: 0.0146
# Epoch 105/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0121 - val_loss: 0.0145
# Epoch 106/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0121 - val_loss: 0.0145
# Epoch 107/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0120 - val_loss: 0.0145
# Epoch 108/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0120 - val_loss: 0.0144
# Epoch 109/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0119 - val_loss: 0.0144
# Epoch 110/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0119 - val_loss: 0.0144
# Epoch 111/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0119 - val_loss: 0.0144
# Epoch 112/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0118 - val_loss: 0.0143
# Epoch 113/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0118 - val_loss: 0.0143
# Epoch 114/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0117 - val_loss: 0.0143
# Epoch 115/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0117 - val_loss: 0.0142
# Epoch 116/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0116 - val_loss: 0.0142
# Epoch 117/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0116 - val_loss: 0.0142
# Epoch 118/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0115 - val_loss: 0.0141
# Epoch 119/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0115 - val_loss: 0.0141
# Epoch 120/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0115 - val_loss: 0.0141
# Epoch 121/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0114 - val_loss: 0.0141
# Epoch 122/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0114 - val_loss: 0.0140
# Epoch 123/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0113 - val_loss: 0.0140
# Epoch 124/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0113 - val_loss: 0.0140
# Epoch 125/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0112 - val_loss: 0.0139
# Epoch 126/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0112 - val_loss: 0.0139
# Epoch 127/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0111 - val_loss: 0.0139
# Epoch 128/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0111 - val_loss: 0.0138
# Epoch 129/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0111 - val_loss: 0.0138
# Epoch 130/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0110 - val_loss: 0.0138
# Epoch 131/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0110 - val_loss: 0.0137
# Epoch 132/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0109 - val_loss: 0.0137
# Epoch 133/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0109 - val_loss: 0.0137
# Epoch 134/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0108 - val_loss: 0.0136
# Epoch 135/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0108 - val_loss: 0.0136
# Epoch 136/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0107 - val_loss: 0.0136
# Epoch 137/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0107 - val_loss: 0.0135
# Epoch 138/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0106 - val_loss: 0.0135
# Epoch 139/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0105 - val_loss: 0.0135
# Epoch 140/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0105 - val_loss: 0.0134
# Epoch 141/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0104 - val_loss: 0.0134
# Epoch 142/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0104 - val_loss: 0.0134
# Epoch 143/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0103 - val_loss: 0.0134
# Epoch 144/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0102 - val_loss: 0.0133
# Epoch 145/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0101 - val_loss: 0.0133
# Epoch 146/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0101 - val_loss: 0.0133
# Epoch 147/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0100 - val_loss: 0.0132
# Epoch 148/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0099 - val_loss: 0.0132
# Epoch 149/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0098 - val_loss: 0.0132
# Epoch 150/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0097 - val_loss: 0.0132
# Epoch 151/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0096 - val_loss: 0.0132
# Epoch 152/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0095 - val_loss: 0.0132
# Epoch 153/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0094 - val_loss: 0.0132
# Epoch 154/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0093 - val_loss: 0.0132
# Epoch 155/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0091 - val_loss: 0.0132
# Epoch 156/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - val_loss: 0.0132
# Epoch 157/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0089 - val_loss: 0.0133
# Epoch 158/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0087 - val_loss: 0.0133
# Epoch 159/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - val_loss: 0.0134
# Epoch 160/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085 - val_loss: 0.0135
# Epoch 161/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - val_loss: 0.0136
# Epoch 162/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0082 - val_loss: 0.0136
# Epoch 163/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081 - val_loss: 0.0137
# Epoch 164/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0080 - val_loss: 0.0138
# Epoch 165/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078 - val_loss: 0.0138
# Epoch 166/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - val_loss: 0.0139
# Epoch 167/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - val_loss: 0.0139
# Epoch 168/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - val_loss: 0.0139
# Epoch 169/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0074 - val_loss: 0.0139
# Epoch 170/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - val_loss: 0.0140
# Epoch 171/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - val_loss: 0.0140
# Epoch 172/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - val_loss: 0.0140
# Epoch 173/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - val_loss: 0.0140
# Epoch 174/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - val_loss: 0.0140
# Epoch 175/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - val_loss: 0.0140
# Epoch 176/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - val_loss: 0.0140
# Epoch 177/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066 - val_loss: 0.0141
# Epoch 178/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065 - val_loss: 0.0137
# Epoch 179/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - val_loss: 0.0149
# Epoch 180/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - val_loss: 0.0134
# Epoch 181/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066 - val_loss: 0.0137
# Epoch 182/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - val_loss: 0.0140

# %%
# Gráfico das curvas de custo do treinamento e validação
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


visualize_loss(history, "Training and Validation Loss")

# %%
# carrega melhor modelo
from tensorflow.keras.models import load_model
model = load_model('trained_models/LSTM.keras',compile=False)

# Faz previsões
train_predict = model.predict(x_train)
val_predict = model.predict(x_val)
test_predict = model.predict(x_test)

# inverso das previsões
train_predict_inv = scaler_Y.inverse_transform(train_predict.reshape(-1, 1))
val_predict_inv = scaler_Y.inverse_transform(val_predict.reshape(-1, 1))
test_predict_inv = scaler_Y.inverse_transform(test_predict.reshape(-1, 1))

# Inverso dos valores reais
train_real_inv = scaler_Y.inverse_transform(y_train.reshape(-1, 1))
val_real_inv = scaler_Y.inverse_transform(y_val.reshape(-1, 1))
test_real_inv = scaler_Y.inverse_transform(y_test.reshape(-1, 1))

# Plota os resultados
plt.figure(figsize=(20,6))
plt.plot(train_real_inv.flatten(), label='Real Train')
plt.plot(train_predict_inv.flatten(), label='Predicted Train')
plt.plot(np.arange(len(y_train), len(y_train) + len(y_val)), val_real_inv.flatten(), label='Real Val')
plt.plot(np.arange(len(y_train), len(y_train) + len(y_val)), val_predict_inv.flatten(), label='Predicted Val')
plt.plot(np.arange(len(y_train) + len(y_val), len(y_train) + len(y_val) + len(y_test)), test_real_inv.flatten(), label='Real Test')
plt.plot(np.arange(len(y_train) + len(y_val), len(y_train) + len(y_val) + len(y_test)), test_predict_inv.flatten(), label='Predicted Test')
plt.legend()
plt.ylabel('ENA_Grande (MWmed)')
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
# Função para calcular as métricas
def calculate_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)
    correlation, _ = pearsonr(y_true, y_pred)
    return mae, rmse, mape, r2, correlation

# Calcula métricas para o conjunto de treinamento
train_mae, train_rmse, train_mape, train_r2, train_correlation = calculate_metrics(train_real_inv[1:].flatten(), train_predict_inv[1:].flatten())

# Calcula métricas para o conjunto de validação
val_mae, val_rmse, val_mape, val_r2, val_correlation = calculate_metrics(val_real_inv[1:].flatten(), val_predict_inv[1:].flatten())

# %%
# Imprime os resultados
print("Modelo LSTM:")
print(f"Conjunto de treinamento: MAE = {train_mae}, RMSE = {train_rmse}, MAPE = {train_mape}, R^2 = {train_r2}, Correlation = {train_correlation}")
print(f"Conjunto de validação: MAE = {val_mae}, RMSE = {val_rmse}, MAPE = {val_mape}, R^2 = {val_r2}, Correlation = {val_correlation}")
#print(f"Conjunto de teste: MAE = {test_mae}, RMSE = {test_rmse}, MAPE = {test_mape}, R^2 = {test_r2}, Correlation = {test_correlation}")
# Out:
# Modelo LSTM:
# Conjunto de treinamento: MAE = 785.6508928129945, RMSE = 1126.7180826524923, MAPE = 27.301235023302024, R^2 = 0.66961301776024, Correlation = 0.8222104490055915
# Conjunto de validação: MAE = 853.5059148615056, RMSE = 1626.2922419689962, MAPE = 15.948282168837405, R^2 = 0.5794835212302687, Correlation = 0.7947837096884882
